# %% [markdown]
# Data Handling and Preprocessing using python

# %%
import pandas as pd
print('Pandas imported successfully!')
# Out:
# Pandas imported successfully!

# %%
data = pd.read_csv('credit_card_fraud_dataset.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#    TransactionID             TransactionDate   Amount  MerchantID  \
# 0              1  2024-04-03 14:15:35.462794  4189.27         688
# 1              2  2024-03-19 13:20:35.462824  2659.71         109
# 2              3  2024-01-08 10:08:35.462834   784.00         394
# 3              4  2024-04-13 23:50:35.462850  3514.40         944
# 4              5  2024-07-12 18:51:35.462858   369.07         475
#
#   TransactionType      Location  IsFraud
# 0          refund   San Antonio        0
# 1          refund        Dallas        0
# 2        purchase      New York        0
# 3        purchase  Philadelphia        0
# 4        purchase       Phoenix        0

# %%
df.transpose()
# Out:
#                                       0                           1      \
# TransactionID                             1                           2
# TransactionDate  2024-04-03 14:15:35.462794  2024-03-19 13:20:35.462824
# Amount                              4189.27                     2659.71
# MerchantID                              688                         109
# TransactionType                      refund                      refund
# Location                        San Antonio                      Dallas
# IsFraud                                   0                           0
#
#                                       2                           3      \
# TransactionID                             3                           4
# TransactionDate  2024-01-08 10:08:35.462834  2024-04-13 23:50:35.462850
# Amount                                784.0                      3514.4
# MerchantID                              394                         944
# ...
